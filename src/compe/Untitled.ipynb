# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
row_data = pd.read_csv('blacksmoke.csv')

# %%
row_data_10 = row_data[:365 * 10]

# %%
row_data_10['bs'].plot()

# %% [markdown]
# - 月曜スタート
# - null check

# %%
row_data_10['x'].head()
# Out:
# 0    451.3
# 1    451.3
# 2    451.3
# 3    451.3
# 4    451.3
# Name: x, dtype: float64

# %%
row_data_10['x'].tail()
# Out:
# 3645    451.3
# 3646    451.3
# 3647    451.3
# 3648    451.3
# 3649    451.3
# Name: x, dtype: float64

# %%
data_a = row_data[:4309]

# %%
data_a.to_csv('./bs_station_a.csv')
